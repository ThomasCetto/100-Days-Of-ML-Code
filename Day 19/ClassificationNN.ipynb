# %%
import torch
import numpy as np
import pandas as pd
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
def create_data(n_samples=1000, noise=0.03):
    X, y = make_circles(n_samples=n_samples, noise=noise)
    return X, y

# %%
X, y = create_data()
df = pd.DataFrame({"cx" : X[:, 0], "cy": X[:, 1], "label": y})
df.head()
# Out:
#          cx        cy  label
# 0 -0.974139 -0.104929      0
# 1 -0.673505 -0.308298      1
# 2  0.845813  0.030183      1
# 3 -0.004235 -1.008520      0
# 4 -0.039800  0.820843      1

# %%
df.plot(kind="scatter", x="cx", y="cy", c="label", cmap="coolwarm")
# Out:
# <Axes: xlabel='cx', ylabel='cy'>
